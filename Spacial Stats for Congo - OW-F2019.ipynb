# %%
import os
import pandas as pd
import geopandas as gpd
# %matplotlib notebook
from shapely.geometry import Point, LineString, Polygon
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shino Bear\\Desktop\\GIS Project Files'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'COD_MiningZones_2017.cpg',
#  'COD_MiningZones_2017.dbf',
#  'COD_MiningZones_2017.prj',
#  'COD_MiningZones_2017.qpj',
#  'COD_MiningZones_2017.shp',
#  'COD_MiningZones_2017.shx',
#  'cod_mining_zones_2017',
#  'cod_mining_zones_2017.zip',
#  'congo_map.png',
#  'congo_mines.png',
#  'deaths.png',
#  'gadm36_COD_0.cpg',
#  'gadm36_COD_0.dbf',
#  'gadm36_COD_0.prj',
#  'gadm36_COD_0.shp',
#  'gadm36_COD_0.shx',
#  'gadm36_COD_1.cpg',
#  'gadm36_COD_1.dbf',
#  'gadm36_COD_1.prj',
#  'gadm36_COD_1.shp',
#  'gadm36_COD_1.shx',
#  'gadm36_COD_2.cpg',
#  'gadm36_COD_2.dbf',
#  'gadm36_COD_2.prj',
#  'gadm36_COD_2.shp',
#  'gadm36_COD_2.shx',
#  'gadm36_COD_shp',
#  'gadm36_COD_shp.zip',
#  'gedevents_2019_10_17.csv',
#  'GIS Project.ipynb',
#  'MINES.png',
#  'Spacial Stats for Congo - OW-F2019.ipynb']

# %% [markdown]
# Using "gedevents_2019_10_17.cvs". Will be provided.

# %%
deaths = pd.read_csv('gedevents_2019_10_17.csv', encoding='latin-1')

# %%
deaths.head()
# Out:
#       id  relid  year  active_year code_status  type_of_violence  \
# 0   6803    NaN  1993         True       Clear                 3
# 1   9607    NaN  1996         True       Clear                 3
# 2   9735    NaN  2003         True       Clear                 3
# 3   9868    NaN  2003         True       Clear                 3
# 4  10068    NaN  1996         True       Clear                 3
#
#    conflict_dset_id  conflict_new_id          conflict_name  dyad_dset_id  \
# 0               554              554     SPLM/A - Civilians          1021
# 1               951              951       CNDD - Civilians          1422
# 2               552              552  CNDD-FDD  - Civilians          1019
# 3               552              552  CNDD-FDD  - Civilians          1019
# 4               951              951       CNDD - Civilians          1422
#
#    dyad_new_id              dyad_name  side_a_dset_id  side_a_new_id  \
# ...

# %% [markdown]
# Too big. Going to cut it down to the important bits.

# %%
cross_98 = deaths.loc[deaths['year'] == 1998]

# %%
cross_98.describe()
# Out:
#                   id  relid    year  type_of_violence  conflict_dset_id  \
# count     118.000000    0.0   118.0        118.000000        118.000000
# mean    25835.177966    NaN  1998.0          1.923729        678.067797
# std     12835.177526    NaN     0.0          0.971005       1070.153018
# min     20199.000000    NaN  1998.0          1.000000        283.000000
# 25%     23366.750000    NaN  1998.0          1.000000        283.000000
# 50%     23694.500000    NaN  1998.0          1.000000        401.500000
# 75%     24315.500000    NaN  1998.0          3.000000        548.000000
# max    157636.000000    NaN  1998.0          3.000000       5002.000000
#
#        conflict_new_id  dyad_dset_id  dyad_new_id  side_a_dset_id  \
# count       118.000000    118.000000   118.000000      118.000000
# mean        678.067797   1077.686441  1077.686441      294.533898
# std        1070.153018   1133.906135  1133.906135      614.618187
# ...

# %% [markdown]
# Still too big. More important bits.

# %%
keep_cols = ['deaths_a', 'deaths_b', 'deaths_civilians', 'deaths_unknown', 'best_est']

# %%
small_98 = cross_98[keep_cols]

# %%
small_98.head()
# Out:
#     deaths_a  deaths_b  deaths_civilians  deaths_unknown  best_est
# 14       122         0                 0               0       122
# 18         0         0                 8               0         8
# 20         0         0                 2               0         2
# 21        20         0                10               0        30
# 32         3         0                 0               0         3

# %%
small_98.describe()
# Out:
#          deaths_a     deaths_b  deaths_civilians  deaths_unknown     best_est
# count  118.000000   118.000000        118.000000      118.000000   118.000000
# mean     6.152542    12.228814         40.627119        8.949153    67.957627
# std     22.147380    92.442397        138.126648       86.724226   181.588922
# min      0.000000     0.000000          0.000000        0.000000     0.000000
# 25%      0.000000     0.000000          0.000000        0.000000     2.000000
# 50%      0.000000     0.000000          1.000000        0.000000    12.000000
# 75%      0.000000     0.000000         11.000000        0.000000    40.000000
# max    146.000000  1000.000000       1000.000000      942.000000  1001.000000

# %% [markdown]
# Boom! There we have it.
# I won't lie, I had my mom help me with the "relid" column because it was blank in the excel sheet, so now that everything works properly I need to go back through everything and make it all clean and compatible again.
